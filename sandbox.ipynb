# %%
import pandas as pd

# %%
df = pd.read_csv("swd nyc 1-20 from apollo.csv")
df
# Out:
#      First Name  Last Name                                   Title  \
# 0          Ivan     Kosyuk                 Chief Executive Officer
# 1       Garrett    Shearer             Owner, Development Director
# 2          Tony   Anderson                                     CEO
# 3         Jared       Tran                 Director Of Engineering
# 4           Rob     Trahan                                 Partner
# ...         ...        ...                                     ...
# 1122     Robert  Santamoor   President and Chief Executive Officer
# 1123      Naomi       Sosa  Executive Business Partner, CEO Office
# 1124      Usman     Farooq                              Co-Founder
# 1125      Dawud     Gordon                        CEO & Co-Founder
# 1126      Frank        Lee              Independent Business Owner
#
#                    Company                        Email Email Status  \
# 0                UA IT Hub        ivan.kosyuk@gart.tech     Verified
# ...

# %%
df = df[df["Email"].notna()]
df
# Out:
#      First Name  Last Name                                           Title  \
# 0          Ivan     Kosyuk                         Chief Executive Officer
# 3         Jared       Tran                         Director Of Engineering
# 4           Rob     Trahan                                         Partner
# 5          Nate      Rubin  Co-founder and Software Engineering Consultant
# 6         Chris    Phoenix                               Managing Director
# ...         ...        ...                                             ...
# 1121       Alex         Hu                                 Co-founder, CTO
# 1122     Robert  Santamoor           President and Chief Executive Officer
# 1123      Naomi       Sosa          Executive Business Partner, CEO Office
# 1124      Usman     Farooq                                      Co-Founder
# 1125      Dawud     Gordon                                CEO & Co-Founder
#
# ...

# %%
len(df[df["Email Status"] == "Verified"])
# Out:
# 622

# %%
df.to_csv("swd nyc 1-20 from apollo.csv", index=False)
